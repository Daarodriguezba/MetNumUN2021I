# %% [markdown]
# # **LAB 3 cognitiveclass.ai Applied Data Science with Python**

# %% [markdown]
# Link e Linkedin es: https://www.linkedin.com/in/daniel-rodriguez-barragan-567b9a20a/

# %% [markdown]
# ## **Python 101 for Data Science**

# %% [markdown]
# <img src ="https://raw.githubusercontent.com/Daarodriguezba/AlgorithmsUN2021I/main/Lab3/daarodriguezbapythonfordatascience.JPG">

# %% [markdown]
# ## **Data Analysis with Python**

# %% [markdown]
# <img src ="https://raw.githubusercontent.com/Daarodriguezba/AlgorithmsUN2021I/main/Lab3/daarodriguezbadataanalysis.JPG">

# %% [markdown]
# ## **Data Visualization with Python**

# %% [markdown]
# <img src ="https://raw.githubusercontent.com/Daarodriguezba/AlgorithmsUN2021I/main/Lab3/daarodriguezbadatavisualization.JPG">
